# %% [markdown]
# ## introdution to matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot();

# %%
plt.plot([1,2,3,4,5]);

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y)
plt.show()

# %%
#1 st method
fig=plt.figure(); ##create  figure
ax=fig.add_subplot()# add some axes
plt.show() #show the graph

# %%
#2nd method
fig=plt.figure() #create a figure
ax=fig.add_axes([1,1,1,1])
ax.plot(x,y) #adding some data
plt.show()

# %%
# 3rd method recommended
fig,ax=plt.subplots()
ax.plot(x,[50,100,200,250]);# add some data
type(fig),type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# ## Matplotlib workflow

# %%
# import matplotlib and get it ready for plotting in jupyter
# %matplotlib inline
import matplotlib.pyplot as plt
# prepare data 
x=[1,2,3,4]
y=[11,12,33,44]
# setup plot 
fig,ax=plt.subplots(figsize=(10,10)) #width,height
#plot data
ax.plot(x,y)
# customize plot
ax.set(title="Simple plot",xlabel="x-axis",ylabel="y-axis")
#sav and show figure
fig.savefig("image/sample-plot.png")

# %% [markdown]
# ## making figures with numpy arrays
# we want:
#  * line plot
#  * scatter plot
#  * bar plot
#  * histogram
#  * sub plot

# %%
import numpy as np

# %%
#create some data
x=np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
#plot the data and create a line plot
fig,ax=plt.subplots()
ax.plot(x,x**2);

# %%
#using the same data to create a scatter plot
fig,ax=plt.subplots();
ax.scatter(x,np.exp(x));

# %%
# Another scatter plot
fig,ax=plt.subplots();
ax.scatter(x,np.sin(x));

# %%
#making a  plot from dictionary
nut_butter_prices={"Almond butter":10,"Peanut butter":8,"Cashew butter":12}
fig,ax=plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax.set(title="Manu's butter",ylabel="price",xlabel="Butter");

# %%
fig,ax=plt.subplots()
ax.barh(list(nut_butter_prices.keys()),nut_butter_prices.values());

# %%
#Creating histogram
# 1) creating random data
x=np.random.randn(1000)
# 2) creating a plot figure
fig,ax=plt.subplots()
# 3) ploting data
ax.hist(x);

# %% [markdown]
# ### two option for subplots

# %%
# subplot option 1
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(10,5))
# ploting different axis
ax1.plot(x,x/2);
ax1.set(title="Figure");
ax2.scatter(np.random.random(10),np.random.random(10));
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
#subplot option 2

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,5))
#plot to each different axis
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.randn(10),np.random.randn(10))
ax[1,0].bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# ## ploting from pandas dataframe

# %%
import pandas as pd

# %%
## creating a  dataframe
car_sales=pd.read_csv("car-sales.csv");
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts=pd.Series(np.random.randn(1000),index=pd. date_range("1/1/2021",periods=1000))
ts=ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"]=car_sales["Price"].str.replace('[\$\,\.]','')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"]=car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sales Date"]=pd.date_range("1/1/2021",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date
# 0  Toyota  White         150043      4   4000 2021-01-01
# 1   Honda    Red          87899      4   5000 2021-01-02
# 2  Toyota   Blue          32549      3   7000 2021-01-03
# 3     BMW  Black          11179      5  22000 2021-01-04
# 4  Nissan  White         213095      4   3500 2021-01-05
# 5  Toyota  Green          99213      4   4500 2021-01-06
# 6   Honda   Blue          45698      4   7500 2021-01-07
# 7   Honda   Blue          54738      4   7000 2021-01-08
# 8  Toyota  White          60000      4   6250 2021-01-09
# 9  Nissan  White          31600      4   9700 2021-01-10

# %%
car_sales["Total Sales"]=car_sales["Price"].astype(int).cumsum();
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2021-01-01         4000
# 1   Honda    Red          87899      4   5000 2021-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2021-01-03        16000
# 3     BMW  Black          11179      5  22000 2021-01-04        38000
# 4  Nissan  White         213095      4   3500 2021-01-05        41500
# 5  Toyota  Green          99213      4   4500 2021-01-06        46000
# 6   Honda   Blue          45698      4   7500 2021-01-07        53500
# 7   Honda   Blue          54738      4   7000 2021-01-08        60500
# 8  Toyota  White          60000      4   6250 2021-01-09        66750
# 9  Nissan  White          31600      4   9700 2021-01-10        76450

# %%
# Let's plot the total sales
car_sales.plot(x="Sales Date",y="Total Sales")
# Out:
# <AxesSubplot:xlabel='Sales Date'>

# %%
#Reasign price column to int
car_sales["Price"]=car_sales["Price"].astype(int)
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter");

# %%
# how about bar graph?
x=np.random.rand(10,4)
x
# turn it into data frame
df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.801881  0.332954  0.488058  0.888136
# 1  0.309704  0.827581  0.110837  0.446296
# 2  0.940820  0.863409  0.509731  0.779535
# 3  0.544431  0.566697  0.780163  0.861887
# 4  0.442667  0.644365  0.956385  0.537987
# 5  0.394387  0.651199  0.452888  0.684839
# 6  0.735997  0.606004  0.346600  0.300856
# 7  0.191396  0.322718  0.808702  0.196736
# 8  0.434765  0.346137  0.489634  0.412649
# 9  0.633141  0.164541  0.970573  0.306140

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2021-01-01         4000
# 1   Honda    Red          87899      4   5000 2021-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2021-01-03        16000
# 3     BMW  Black          11179      5  22000 2021-01-04        38000
# 4  Nissan  White         213095      4   3500 2021-01-05        41500
# 5  Toyota  Green          99213      4   4500 2021-01-06        46000
# 6   Honda   Blue          45698      4   7500 2021-01-07        53500
# 7   Honda   Blue          54738      4   7000 2021-01-08        60500
# 8  Toyota  White          60000      4   6250 2021-01-09        66750
# 9  Nissan  White          31600      4   9700 2021-01-10        76450

# %%
car_sales.plot(x="Make",y="Odometer (KM)",kind="bar");

# %%
# how about histogram?
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# lets try on another data set
heart_disease=pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# create a histogram for age column to show age distribution
heart_disease["age"].plot.hist(bins=10);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize=(10,30),subplots=True);

# %% [markdown]
# ### Which one should you use? (pyplot vs matplotlib oo method?)
# * when ploting someting quikly,okey to use the pyplot method
# * when  ploting something more advance,use the OO method

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50=heart_disease[heart_disease["age"] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
#pyplot method,ploting directly from pandas dataframe
over_50.plot(kind="scatter",x='age',y="chol",c="target");

# %%
#OO method
fig,ax=plt.subplots(figsize=(10,7))
over_50.plot(kind="scatter",x='age',y="chol",c="target",ax=ax)
#ax.set_xlim([45,100]);
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %% [markdown]
# ## OO method from scratch

# %%
fig,ax=plt.subplots(figsize=(10,6))
#plot the data
scatter=ax.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"])
# Customize the plot
ax.set(title="Heart Diseases and Cholesterol levels0",xlabel="Age",ylabel="Cholesterol");
ax.legend(*scatter.legend_elements(),title="Target");
# Add a horizontal line
ax.axhline(over_50["chol"].mean(),linestyle='--');
